# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

# %%
url='https://www.flipkart.com/search?q=samsung%20mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')
#print(soup.prettify())

# %%
# data of product name
name = soup.find_all('div',class_='KzDlHZ')
names=[]
for i in name[0:20]:
    data = i.get_text()
    names.append(data)
# data of final price details
price = soup.find_all('div',attrs={'class':'Nx9bqj _4b5DiR'})
prices=[]
for i in price[0:20]:
    data=i.get_text()
    numeric_price = re.sub(r'[^\d]', '', data)
    prices.append(numeric_price)
# data of ram details
ram = soup.find_all('li',class_='J+igdf')
rams=[]
for i in ram[0:20]:
    data=i.get_text()
    rams.append(data)
# data of rating details
rating = soup.find_all('div',class_='XQDdHH')
ratings=[]
for i in rating[0:20]:
    data=i.get_text()
    ratings.append(data)
# data of discount details
discount = soup.find_all('div',class_='UkUFwK')
discounts=[]
for i in discount[0:20]:
    data=i.get_text()
    discounts.append(data)
# data of real price
real_price = soup.find_all('div',class_='yRaY8j ZYYwLA')
real_prices=[]
for i in real_price[0:20]:
    data=i.get_text()
    numeric_price = re.sub(r'[^\d]', '', data)
    real_prices.append(numeric_price)
# link of the products
link = soup.find_all('a',class_='CGtC98')
links=[]
for i in link[0:20]:
    data='https://www.flipkart.com'+i['href']
    links.append(data)
df=pd.DataFrame()
df['names']=names
df['links']=links
df['ratings']=ratings
df['real_price']=real_prices
df['discounts']=discounts
df['final_price']=prices
df
# Out:
#                                                 names  \
# 0           SAMSUNG Galaxy F05 (Twilight Blue, 64 GB)
# 1               SAMSUNG Galaxy S23 5G (Cream, 256 GB)
# 2               SAMSUNG Galaxy S23 5G (Green, 128 GB)
# 3            SAMSUNG Galaxy A14 5G (Dark Red, 128 GB)
# 4       SAMSUNG Galaxy M35 5G (DayBreak Blue, 128 GB)
# 5               SAMSUNG Galaxy S23 5G (Cream, 128 GB)
# 6       SAMSUNG Galaxy S23 5G (Phantom Black, 256 GB)
# 7            SAMSUNG Galaxy S23 FE (Graphite, 128 GB)
# 8            SAMSUNG Galaxy S23 5G (Lavender, 256 GB)
# 9       SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)
# 10     SAMSUNG Galaxy S24+ 5G (Cobalt Violet, 256 GB)
# 11              SAMSUNG Galaxy S23 5G (Green, 256 GB)
# 12        SAMSUNG Galaxy S24+ 5G (Onyx Black, 256 GB)
# 13           SAMSUNG Galaxy A14 5G (Dark Red, 128 GB)
# 14            SAMSUNG Galaxy A14 5G (Dark Red, 64 GB)
# 15    SAMSUNG Galaxy A35 5G (Awesome Iceblue, 128 GB)
# 16              SAMSUNG Galaxy A14 5G (Black, 128 GB)
# 17  SAMSUNG Galaxy S23 Ultra 5G (Phantom Black, 25...
# 18       SAMSUNG Galaxy A35 5G (Awesome Navy, 128 GB)
# 19      SAMSUNG Galaxy F15 5G (Groovy Violet, 128 GB)
#
#                                                 links ratings real_price  \
# 0   https://www.flipkart.com/samsung-galaxy-f05-tw...     4.2       9999
# 1   https://www.flipkart.com/samsung-galaxy-s23-5g...     4.6      95999
# 2   https://www.flipkart.com/samsung-galaxy-s23-5g...     4.6      89999
# 3   https://www.flipkart.com/samsung-galaxy-a14-5g...     4.2      20999
# 4   https://www.flipkart.com/samsung-galaxy-m35-5g...     4.4      24499
# 5   https://www.flipkart.com/samsung-galaxy-s23-5g...     4.6      89999
# 6   https://www.flipkart.com/samsung-galaxy-s23-5g...     4.6      95999
# 7   https://www.flipkart.com/samsung-galaxy-s23-fe...     4.4      79999
# 8   https://www.flipkart.com/samsung-galaxy-s23-5g...     4.6      95999
# 9   https://www.flipkart.com/samsung-galaxy-s23-5g...     4.6      89999
# 10  https://www.flipkart.com/samsung-galaxy-s24-5g...     4.5      99999
# 11  https://www.flipkart.com/samsung-galaxy-s23-5g...     4.6      95999
# 12  https://www.flipkart.com/samsung-galaxy-s24-5g...     4.5      15499
# 13  https://www.flipkart.com/samsung-galaxy-a14-5g...     4.2      18499
# 14  https://www.flipkart.com/samsung-galaxy-a14-5g...     4.2      33999
# 15  https://www.flipkart.com/samsung-galaxy-a35-5g...     4.3      20999
# 16  https://www.flipkart.com/samsung-galaxy-a14-5g...     4.2     149999
# 17  https://www.flipkart.com/samsung-galaxy-s23-ul...     4.6      33999
# 18  https://www.flipkart.com/samsung-galaxy-a35-5g...     4.3      16999
# 19  https://www.flipkart.com/samsung-galaxy-f15-5g...     4.2      48999
#
#    discounts final_price
# 0    20% off        7999
# 1    50% off       47999
# 2    52% off       42999
# 3    42% off       11999
# 4    36% off       15456
# 5    52% off       42999
# 6    50% off       47999
# 7    56% off       34999
# 8    50% off       47999
# 9    52% off       42999
# 10   32% off       67999
# 11   50% off       47999
# 12   29% off       99999
# 13   45% off       10999
# 14    8% off        9999
# 15   42% off       30999
# 16   48% off       11999
# 17    8% off       76963
# 18   11% off       30999
# 19    6% off       14999

# %%
df.to_csv('D:\chrome\mobiles_dataset.csv')
